# %%
import pandas as pd # Python library for data analysis and data frame
import numpy as np # Numerical Python library for linear algebra and computations
pd.set_option('display.max_columns', None) # code to display all columns
import heapq

# Visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import date, datetime # for manupulating time and date columns

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler # For handling categorical column and scaling numeric columns
# Libraries for clustering and evaluation
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
#Importo libres
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

# %%
#Read the file
df=pd.read_csv("../train.csv", sep=",", index_col="ID_code")
df.head()
# Out:
#          target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# ID_code
# train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#            var_7   var_8   var_9  var_10   var_11   var_12   var_13  var_14  \
# ID_code
# train_0  18.6266 -4.9200  5.7470  2.9252   3.1821  14.0137   0.5745  8.7989
# train_1  16.5338  3.1468  8.0851 -0.4032   8.0585  14.0239   8.4135  5.4345
# train_2  14.6155 -4.9193  5.9525 -0.3249 -11.2648  14.1929   7.3124  7.5244
# train_3  14.9250 -5.8609  8.2450  2.3061   2.8102  13.8463  11.9704  6.4569
# train_4  19.2514  6.2654  7.6784 -9.4458 -12.1419  13.8481   7.8895  7.7894
#
# ...

# %%
#Cargo los datos de los dataframe
X=df.drop("target", axis=1)
y=df["target"]

# %%
#Divido el dataframe en test y train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Escalamos los datos para tener una distribución homogenea de los datos
scaler = MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
transformed_x_train = pd.DataFrame(X_train)
transformed_x_train.columns = X.columns
transformed_x_train
# Out:
#            var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# 0       0.309699  0.843620  0.532900  0.660710  0.358191  0.403162  0.414560
# 1       0.483094  0.755623  0.379767  0.509476  0.714270  0.334240  0.532197
# 2       0.556605  0.590558  0.761343  0.659175  0.428108  0.434761  0.425029
# 3       0.280145  0.670148  0.372865  0.288687  0.446010  0.439431  0.663948
# 4       0.423317  0.651096  0.298233  0.425173  0.565424  0.814132  0.805835
# ...          ...       ...       ...       ...       ...       ...       ...
# 133995  0.552950  0.675325  0.456046  0.637827  0.661565  0.220003  0.420119
# 133996  0.434383  0.573792  0.612363  0.415973  0.421192  0.352918  0.285089
# 133997  0.821822  0.631423  0.491219  0.639846  0.372057  0.737881  0.480036
# 133998  0.479539  0.884785  0.652894  0.677885  0.399151  0.432672  0.134164
# 133999  0.561469  0.457565  0.417089  0.400325  0.587396  0.651680  0.318759
#
# ...

# %%
#incializo PCA 
pca = PCA()

# %% [markdown]
# ### Genero varios PCA para distintas cantidades de dimensiones para luego calcular el accuracy

# %%
#PCA 1 variables
pca=PCA(n_components=1)
X_train_1 = pca.fit_transform(X_train)
X_test_1 = pca.transform(X_test)

# %%
#PCA 10 variables
pca=PCA(n_components=10)
X_train_10 = pca.fit_transform(X_train)
X_test_10 = pca.transform(X_test)

# %%
#PCA 30 variables
pca=PCA(n_components=30)
X_train_30 = pca.fit_transform(X_train)
X_test_30 = pca.transform(X_test)

# %%
#PCA 50 variables
pca=PCA(n_components=50)
X_train_50 = pca.fit_transform(X_train)
X_test_50 = pca.transform(X_test)

# %%
#PCA 75 variables
pca=PCA(n_components=75)
X_train_75 = pca.fit_transform(X_train)
X_test_75 = pca.transform(X_test)

# %%
#PCA 100 variables
pca=PCA(n_components=100)
X_train_100 = pca.fit_transform(X_train)
X_test_100 = pca.transform(X_test)

# %%
#PCA 125 variables
pca=PCA(n_components=125)
X_train_125 = pca.fit_transform(X_train)
X_test_125 = pca.transform(X_test)

# %%
#Inicializo el modelo
model_rf = RandomForestClassifier(max_depth=2, random_state=0)
model_rf_1 = RandomForestClassifier(max_depth=2, random_state=0)
model_rf_10=RandomForestClassifier(max_depth=2, random_state=0)
model_rf_30=RandomForestClassifier(max_depth=2, random_state=0)
model_rf_50=RandomForestClassifier(max_depth=2, random_state=0)
model_rf_75=RandomForestClassifier(max_depth=2, random_state=0)
model_rf_100=RandomForestClassifier(max_depth=2, random_state=0)
model_rf_125=RandomForestClassifier(max_depth=2, random_state=0)

# %%
#Entreno para todas las variables transforamdas
model_rf.fit(X_train, y_train)
y_pred= model_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
cross_val=cross_val_score(model_rf,X_test,y_test,cv=5)
print(accuracy,cross_val)
# Out:
# 0.8976666666666666 [0.89772727 0.89765152 0.89765152 0.89765152 0.89765152]

# %%
#Entreno 1
model_rf_1.fit(X_train_1, y_train)
y_pred_1= model_rf_1.predict(X_test_1)
accuracy_1 = accuracy_score(y_test, y_pred_1)
cross_val_1=cross_val_score(model_rf_1,X_test,y_test,cv=5)
print(accuracy_1,cross_val_1)
# Out:
# 0.8976666666666666 [0.89772727 0.89765152 0.89765152 0.89765152 0.89765152]

# %%
#Entreno 10
model_rf_10.fit(X_train_10, y_train)
y_pred_10= model_rf_10.predict(X_test_10)
accuracy_10 = accuracy_score(y_test, y_pred_10)
cross_val_10=cross_val_score(model_rf_10,X_test,y_test,cv=5)
print(accuracy_10,cross_val_10)
# Out:
# 0.8976666666666666 [0.89772727 0.89765152 0.89765152 0.89765152 0.89765152]

# %%
#Entreno 30
model_rf_30.fit(X_train_30, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#Entreno 50
model_rf_50.fit(X_train_50, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#Entreno 75
model_rf_75.fit(X_train_75, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#Entreno 100
model_rf_100.fit(X_train_100, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#Entreno 125
model_rf_125.fit(X_train_125, y_train)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
# Predicción para cada modelo
y_pred = model_rf.predict(X_test)
y_pred_10= model_rf_10.predict(X_test_10)
y_pred_30= model_rf_30.predict(X_test_30)
y_pred_50= model_rf_50.predict(X_test_50)
y_pred_75= model_rf_75.predict(X_test_75)
y_pred_100= model_rf_100.predict(X_test_100)
y_pred_125= model_rf_125.predict(X_test_125)

# %%
#Calculo accuracy
accuracy = accuracy_score(y_test, y_pred)
accuracy_10 = accuracy_score(y_test, y_pred_10)
accuracy_30 = accuracy_score(y_test, y_pred_30)
accuracy_50 = accuracy_score(y_test, y_pred_50)
accuracy_75 = accuracy_score(y_test, y_pred_75)
accuracy_100 = accuracy_score(y_test, y_pred_100)
accuracy_125 = accuracy_score(y_test, y_pred_125)
print(accuracy,accuracy_10,accuracy_30,accuracy_50,accuracy_75,accuracy_100,accuracy_125)
# Out:
# 0.8976666666666666 0.8976666666666666 0.8976666666666666 0.8976666666666666 0.8976666666666666 0.8976666666666666 0.8976666666666666

# %%
X_train.shape,X_train_10.shape,X_train_1.shape
# Out:
# ((134000, 200), (134000, 10), (134000, 1))
